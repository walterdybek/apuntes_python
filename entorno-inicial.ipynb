# %% [markdown]
# ## Hola mundo
# primer codigo python
#
# $e^i - 1=0$

# %%
a=20
a+=1
print(a)
# Out:
# 21

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')

sns.scatterplot(x='sepal_length', y='sepal_width',hue='species', data=iris)
plt.grid()
plt.show()

# %% [markdown]
# - item 1
# - item 2
# - item 3

# %%
2 < 10
# Out:
# True

# %%
(2).__lt__(10)
# Out:
# False

# %%
10 == 1
# Out:
# False

# %%
a = 10; b =20 

if a < b :
    print('a < b')
else:
        print('a >= b')
# Out:
# a < b

# %%
if True :
    print('este bloque siempre se ejecuta')

# %%
my_list = [1,2,3]
print(my_list)

if my_list:
    print('my_list tiene elementos')
# Out:
# [1, 2, 3]
# my_list tiene elementos

# %%
my_list = []
print(my_list)

if my_list:
    print('my_list tiene elementos')
else:
    print('my_list no tiene elementos')
# Out:
# []
# my_list no tiene elementos

# %%
my_list = [10,20,30, 40 ]
my_list
# Out:
# [10, 20, 30, 40]

# %%
my_list.pop()
# Out:
# 40

# %%
my_list
# Out:
# [10, 20, 30]

# %%
my_tuple = (1,2,3)
my_tuple
# Out:
# (1, 2, 3)

# %%
my_tuple = 1,2,3
my_tuple
# Out:
# (1, 2, 3)

# %%
my_empty_tuple = ()
my_empty_tuple

# %%
if not my_empty_tuple :
    print('my_empty_tuple no tiene elementos')
else:
    print('my_empty_tuple tiene elementos')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 if not my_empty_tuple :
#       2     print('my_empty_tuple no tiene elementos')
#       3 else:
#
# NameError: name 'my_empty_tuple' is not defined

# %%
saludo = 'hola mundo'
saludo
# Out:
# 'hola mundo'

# %%
"aba".replace('a','o')
# Out:
# 'obo'

# %%
my_str = "aba"
print(hex(id(my_str)))
my_str = my_str.replace('a','b')
print(hex(id(my_str)))
# Out:
# 0x19f90fc59e0
# 0x19f90f9a820

# %%
multiline = """hola
mundo"""

print(multiline)
# Out:
# hola
# mundo
